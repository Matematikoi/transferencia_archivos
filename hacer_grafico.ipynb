# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.style as style
style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

# %%
data = pd.read_csv('acumulado.csv')
data['tiempo'] = (data.t1+data.t2+data.t3)/3.0
data.set_index('peso',inplace = True)
data.groupby('tipo_transferencia')['tiempo'].plot(legend=True)
plt.xlabel("Peso del archivo")
plt.ylabel("Segundos")
plt.title("Comparación de velocidad entre distintos\nmetodos de transferencia entre procesos")
plt.savefig("imagen_resultado.png",dpi=300)

# %%
data
# Out:
#        tipo_transferencia     t1     t2     t3    tiempo
# peso
# 1k                  pipes  0.002  0.002  0.002  0.002000
# 10k                 pipes  0.002  0.002  0.002  0.002000
# 100k                pipes  0.002  0.002  0.002  0.002000
# 1m                  pipes  0.004  0.005  0.004  0.004333
# 10m                 pipes  0.021  0.024  0.021  0.022000
# 100m                pipes  0.182  0.208  0.180  0.190000
#  1k      cliente_servidor  0.001  0.001  0.001  0.001000
#  10k     cliente_servidor  0.001  0.001  0.001  0.001000
#  100k    cliente_servidor  0.001  0.001  0.001  0.001000
#  1m      cliente_servidor  0.002  0.002  0.002  0.002000
#  10m     cliente_servidor  0.015  0.013  0.014  0.014000
#  100m    cliente_servidor  0.137  0.124  0.122  0.127667
# 1k               archivos  0.100  0.020  0.024  0.048000
# 10k              archivos  0.004  0.003  0.003  0.003333
# 100k             archivos  0.004  0.004  0.004  0.004000
# 1m               archivos  0.007  0.009  0.008  0.008000
# 10m              archivos  0.048  0.051  0.046  0.048333
# 100m             archivos  0.957  0.754  0.980  0.897000
# 1k     memoria_compartida  0.003  0.003  0.003  0.003000
# 10k    memoria_compartida  0.004  0.003  0.003  0.003333
# 100k   memoria_compartida  0.002  0.003  0.003  0.002667
# 1m     memoria_compartida  0.005  0.007  0.005  0.005667
# 10m    memoria_compartida  0.032  0.045  0.042  0.039667
# 100m   memoria_compartida  0.261  0.236  0.260  0.252333
